# %% [markdown]
# # Lab 1: Spark Batch Processing
#
# ## 🎯 Objectives
# - Master Spark DataFrame operations
# - Learn data processing patterns
# - Understand performance optimization
# - Practice with real-world datasets
#
# ## 📋 Prerequisites
# - Spark cluster running
# - Basic Python knowledge
# - Understanding of SQL concepts
#
# ## 🏗️ Architecture Overview
# ```
# Data Sources → Spark DataFrame → Transformations → Actions → Results
#      ↓              ↓                ↓              ↓
#    CSV/JSON    Select/Filter    GroupBy/Join    Collect/Write
#    Parquet     WithColumn      Aggregations    Database/File
#    Database    Drop/Rename     Window Functions
# ```
#
# ## 📊 Sample Datasets
# - **Sales Data**: Transaction records with customer, product, timestamp
# - **Customer Data**: Demographics, preferences, purchase history
# - **Product Catalog**: Product details, categories, pricing

# %%
# Install and Import Dependencies
# %pip install pyspark findspark pandas numpy pyarrow psycopg2-binary sqlalchemy

import findspark
findspark.init()

from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.window import Window
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import random
import builtins  # Import builtins để sử dụng Python's built-in round()

print("✅ Dependencies installed and imported successfully!")
# Out:
# Requirement already satisfied: pyspark in /home/son/Documents/IT4931_data_management_and_processing_lab_materials/.venv/lib/python3.10/site-packages (4.1.1)
# Requirement already satisfied: findspark in /home/son/Documents/IT4931_data_management_and_processing_lab_materials/.venv/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: pandas in /home/son/Documents/IT4931_data_management_and_processing_lab_materials/.venv/lib/python3.10/site-packages (2.1.4)
# Requirement already satisfied: numpy in /home/son/Documents/IT4931_data_management_and_processing_lab_materials/.venv/lib/python3.10/site-packages (1.24.3)
# Requirement already satisfied: pyarrow in /home/son/Documents/IT4931_data_management_and_processing_lab_materials/.venv/lib/python3.10/site-packages (23.0.1)
# Requirement already satisfied: psycopg2-binary in /home/son/Documents/IT4931_data_management_and_processing_lab_materials/.venv/lib/python3.10/site-packages (2.9.11)
# Requirement already satisfied: sqlalchemy in /home/son/Documents/IT4931_data_management_and_processing_lab_materials/.venv/lib/python3.10/site-packages (2.0.49)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in /home/son/Documents/IT4931_data_management_and_processing_lab_materials/.venv/lib/python3.10/site-packages (from pyspark) (0.10.9.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/son/Documents/IT4931_data_management_and_processing_lab_materials/.venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/son/Documents/IT4931_data_management_and_processing_lab_materials/.venv/lib/python3.10/site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/son/Documents/IT4931_data_management_and_processing_lab_materials/.venv/lib/python3.10/site-packages (from pandas) (2026.1)
# Requirement already satisfied: greenlet>=1 in /home/son/Documents/IT4931_data_management_and_processing_lab_materials/.venv/lib/python3.10/site-packages (from sqlalchemy) (3.3.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/son/Documents/IT4931_data_management_and_processing_lab_materials/.venv/lib/python3.10/site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: six>=1.5 in /home/son/Documents/IT4931_data_management_and_processing_lab_materials/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# ✅ Dependencies installed and imported successfully!

# %%
from pyspark.sql import SparkSession
from pyspark import SparkContext

# Dừng context bị lỗi nếu có
try:
    SparkContext.getOrCreate().stop()
except:
    pass

spark = SparkSession.builder \
    .appName("SparkBatchProcessingLab") \
    .master("local[*]") \
    .config("spark.sql.adaptive.enabled", "true") \
    .config("spark.sql.adaptive.coalescePartitions.enabled", "true") \
    .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
    .getOrCreate()

sc = spark.sparkContext

# %%
# Set log level to reduce verbosity
spark.sparkContext.setLogLevel("WARN")

print("🚀 Spark Session initialized successfully!")
print(f"📊 Spark Version: {spark.version}")
print(f"🔗 Master URL: {spark.sparkContext.master}")
#print(f"👥 Available Executors: {spark.sparkContext.statusTracker().getExecutorInfos()}")
# Out:
# 🚀 Spark Session initialized successfully!
# 📊 Spark Version: 4.1.1
# 🔗 Master URL: local[*]

# %%
# Create Sample Data for Spark Lab
print("📊 Creating sample datasets for Spark Batch Processing Lab...")

# Sample Sales Data
sales_data = []
products = ['Laptop', 'Phone', 'Tablet', 'Headphones', 'Camera', 'Monitor', 'Keyboard', 'Mouse']
customers = ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve', 'Frank', 'Grace', 'Henry']
categories = ['Electronics', 'Accessories', 'Computing']

for i in range(1000):
    sales_data.append({
        'sale_id': f'SALE_{i+1:04d}',
        'customer_name': random.choice(customers),
        'product_name': random.choice(products),
        'category': random.choice(categories),
        'quantity': random.randint(1, 5),
        'unit_price': __builtins__.round(random.uniform(50, 2000), 2),  # Sử dụng Python's built-in round()
        'sale_date': (datetime.now() - timedelta(days=random.randint(0, 365))).strftime('%Y-%m-%d'),
        'region': random.choice(['North', 'South', 'East', 'West', 'Central'])
    })

# Sample Customer Data
customer_data = []
for customer in customers:
    customer_data.append({
        'customer_name': customer,
        'age': random.randint(25, 65),
        'city': random.choice(['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']),
        'membership_level': random.choice(['Bronze', 'Silver', 'Gold', 'Platinum']),
        'join_date': (datetime.now() - timedelta(days=random.randint(30, 1000))).strftime('%Y-%m-%d'),
        'total_purchases': random.randint(5, 50)
    })

# Sample Product Data
product_data = []
for product in products:
    product_data.append({
        'product_name': product,
        'category': random.choice(categories),
        'brand': random.choice(['TechCorp', 'ElectroMax', 'DigitalPro', 'SmartTech']),
        'cost_price': __builtins__.round(random.uniform(30, 1500), 2),  # Sử dụng Python's built-in round()
        'in_stock': random.randint(0, 100),
        'supplier': random.choice(['SupplierA', 'SupplierB', 'SupplierC'])
    })

print(f"✅ Sample data created:")
print(f"   📊 Sales records: {len(sales_data)}")
print(f"   👥 Customer records: {len(customer_data)}")
print(f"   📦 Product records: {len(product_data)}")
# Out:
# 📊 Creating sample datasets for Spark Batch Processing Lab...
# ✅ Sample data created:
#    📊 Sales records: 1000
#    👥 Customer records: 8
#    📦 Product records: 8

# %%
# Create Spark DataFrames
print("🔄 Creating Spark DataFrames from sample data...")

# Convert to Spark DataFrames
sales_df = spark.createDataFrame(sales_data)
customers_df = spark.createDataFrame(customer_data)
products_df = spark.createDataFrame(product_data)

# Show schema and sample data
print("\n📊 Sales DataFrame Schema:")
sales_df.printSchema()

print("\n📊 Sales DataFrame Sample:")
sales_df.show(5, truncate=False)

print("\n👥 Customers DataFrame Schema:")
customers_df.printSchema()

print("\n👥 Customers DataFrame Sample:")
customers_df.show(5, truncate=False)

print("\n📦 Products DataFrame Schema:")
products_df.printSchema()

print("\n📦 Products DataFrame Sample:")
products_df.show(5, truncate=False)

print(f"\n✅ DataFrames created successfully!")
print(f"   📊 Sales: {sales_df.count()} records")
print(f"   👥 Customers: {customers_df.count()} records") 
print(f"   📦 Products: {products_df.count()} records")
# Out:
# 🔄 Creating Spark DataFrames from sample data...
#
# 📊 Sales DataFrame Schema:
# root
#  |-- category: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- quantity: long (nullable = true)
#  |-- region: string (nullable = true)
#  |-- sale_date: string (nullable = true)
#  |-- sale_id: string (nullable = true)
#  |-- unit_price: double (nullable = true)
#
#
# 📊 Sales DataFrame Sample:
# +-----------+-------------+------------+--------+-------+----------+---------+----------+
# |category   |customer_name|product_name|quantity|region |sale_date |sale_id  |unit_price|
# +-----------+-------------+------------+--------+-------+----------+---------+----------+
# |Computing  |Alice        |Headphones  |1       |South  |2025-07-19|SALE_0001|1932.68   |
# |Electronics|Frank        |Monitor     |5       |Central|2025-07-05|SALE_0002|1136.68   |
# |Accessories|Eve          |Tablet      |2       |Central|2026-01-03|SALE_0003|762.13    |
# |Computing  |Eve          |Camera      |4       |South  |2025-08-07|SALE_0004|1762.18   |
# |Electronics|Bob          |Camera      |3       |East   |2025-08-15|SALE_0005|193.67    |
# +-----------+-------------+------------+--------+-------+----------+---------+----------+
# only showing top 5 rows
#
# 👥 Customers DataFrame Schema:
# root
#  |-- age: long (nullable = true)
#  |-- city: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- join_date: string (nullable = true)
#  |-- membership_level: string (nullable = true)
#  |-- total_purchases: long (nullable = true)
#
#
# 👥 Customers DataFrame Sample:
# +---+-------+-------------+----------+----------------+---------------+
# |age|city   |customer_name|join_date |membership_level|total_purchases|
# +---+-------+-------------+----------+----------------+---------------+
# |39 |Chicago|Alice        |2024-08-17|Bronze          |13             |
# |28 |Houston|Bob          |2025-10-09|Platinum        |32             |
# |41 |Chicago|Charlie      |2025-09-15|Bronze          |6              |
# |26 |Chicago|Diana        |2025-09-23|Bronze          |30             |
# |40 |Houston|Eve          |2024-07-25|Gold            |31             |
# +---+-------+-------------+----------+----------------+---------------+
# only showing top 5 rows
#
# 📦 Products DataFrame Schema:
# root
#  |-- brand: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- cost_price: double (nullable = true)
#  |-- in_stock: long (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- supplier: string (nullable = true)
#
#
# 📦 Products DataFrame Sample:
# +----------+-----------+----------+--------+------------+---------+
# |brand     |category   |cost_price|in_stock|product_name|supplier |
# +----------+-----------+----------+--------+------------+---------+
# |ElectroMax|Electronics|334.52    |38      |Laptop      |SupplierC|
# |DigitalPro|Computing  |1497.65   |20      |Phone       |SupplierB|
# |SmartTech |Computing  |893.81    |36      |Tablet      |SupplierB|
# |ElectroMax|Accessories|985.47    |23      |Headphones  |SupplierC|
# |DigitalPro|Computing  |418.75    |2       |Camera      |SupplierA|
# +----------+-----------+----------+--------+------------+---------+
# only showing top 5 rows
#
# ✅ DataFrames created successfully!
#    📊 Sales: 1000 records
#    👥 Customers: 8 records
#    📦 Products: 8 records

# %% [markdown]
# ## Exercise 1: Basic DataFrame Operations
#
# ### 🎯 **Learning Objectives:**
# - Master DataFrame transformations
# - Learn filtering and selection patterns
# - Practice column operations
# - Understand DataFrame caching strategies
#
# ### 📚 **Key Concepts:**
# 1. **Transformations**: Lazy operations that build execution plan
# 2. **Actions**: Operations that trigger computation
# 3. **Column Operations**: Working with DataFrame columns
# 4. **Caching**: Optimizing repeated operations

# %%
# Exercise 1: Basic DataFrame Operations
print("🔧 Exercise 1: Basic DataFrame Operations")

print("\n1️⃣ Filtering Operations:")
print("   Filter sales with quantity > 2 and unit_price > 500")

filtered_sales = sales_df.filter(
    (col("quantity") > 2) & (col("unit_price") > 500)
)

print(f"   📊 Filtered records: {filtered_sales.count()}")
filtered_sales.show(5)

print("\n2️⃣ Column Selection and Renaming:")
print("   Select specific columns and rename them")

selected_sales = sales_df.select(
    col("sale_id").alias("transaction_id"),
    col("customer_name").alias("customer"),
    col("product_name").alias("product"),
    col("quantity"),
    col("unit_price").alias("price")
)

selected_sales.show(5)

print("\n3️⃣ Adding Calculated Columns:")
print("   Add total_amount column (quantity * unit_price)")

sales_with_total = sales_df.withColumn(
    "total_amount", 
    col("quantity") * col("unit_price")
).withColumn(
    "discount_applied",
    when(col("total_amount") > 1000, col("total_amount") * 0.1).otherwise(0)
).withColumn(
    "final_amount",
    col("total_amount") - col("discount_applied")
)

sales_with_total.show(5)

print("\n4️⃣ Data Type Conversions:")
print("   Convert sale_date to proper date type")

sales_with_dates = sales_df.withColumn(
    "sale_date", 
    to_date(col("sale_date"), "yyyy-MM-dd")
).withColumn(
    "sale_year",
    year(col("sale_date"))
).withColumn(
    "sale_month", 
    month(col("sale_date"))
)

sales_with_dates.select("sale_id", "sale_date", "sale_year", "sale_month").show(5)

print("\n✅ Basic DataFrame operations completed!")
# Out:
# 🔧 Exercise 1: Basic DataFrame Operations
#
# 1️⃣ Filtering Operations:
#    Filter sales with quantity > 2 and unit_price > 500
#    📊 Filtered records: 467
# +-----------+-------------+------------+--------+-------+----------+---------+----------+
# |   category|customer_name|product_name|quantity| region| sale_date|  sale_id|unit_price|
# +-----------+-------------+------------+--------+-------+----------+---------+----------+
# |Electronics|        Frank|     Monitor|       5|Central|2025-07-05|SALE_0002|   1136.68|
# |  Computing|          Eve|      Camera|       4|  South|2025-08-07|SALE_0004|   1762.18|
# |Electronics|        Grace|       Mouse|       5|Central|2026-03-09|SALE_0007|    1376.6|
# |  Computing|        Frank|  Headphones|       4|  North|2026-02-21|SALE_0009|    1252.3|
# |Accessories|      Charlie|       Phone|       4|  North|2026-01-24|SALE_0010|   1979.72|
# +-----------+-------------+------------+--------+-------+----------+---------+----------+
# only showing top 5 rows
#
# 2️⃣ Column Selection and Renaming:
#    Select specific columns and rename them
# +--------------+--------+----------+--------+-------+
# |transaction_id|customer|   product|quantity|  price|
# +--------------+--------+----------+--------+-------+
# |     SALE_0001|   Alice|Headphones|       1|1932.68|
# |     SALE_0002|   Frank|   Monitor|       5|1136.68|
# |     SALE_0003|     Eve|    Tablet|       2| 762.13|
# |     SALE_0004|     Eve|    Camera|       4|1762.18|
# |     SALE_0005|     Bob|    Camera|       3| 193.67|
# +--------------+--------+----------+--------+-------+
# only showing top 5 rows
#
# 3️⃣ Adding Calculated Columns:
#    Add total_amount column (quantity * unit_price)
# +-----------+-------------+------------+--------+-------+----------+---------+----------+-----------------+------------------+------------+
# |   category|customer_name|product_name|quantity| region| sale_date|  sale_id|unit_price|     total_amount|  discount_applied|final_amount|
# +-----------+-------------+------------+--------+-------+----------+---------+----------+-----------------+------------------+------------+
# |  Computing|        Alice|  Headphones|       1|  South|2025-07-19|SALE_0001|   1932.68|          1932.68|193.26800000000003|    1739.412|
# |Electronics|        Frank|     Monitor|       5|Central|2025-07-05|SALE_0002|   1136.68|5683.400000000001|            568.34|     5115.06|
# |Accessories|          Eve|      Tablet|       2|Central|2026-01-03|SALE_0003|    762.13|          1524.26|152.42600000000002|    1371.834|
# |  Computing|          Eve|      Camera|       4|  South|2025-08-07|SALE_0004|   1762.18|          7048.72| 704.8720000000001|    6343.848|
# |Electronics|          Bob|      Camera|       3|   East|2025-08-15|SALE_0005|    193.67|           581.01|               0.0|      581.01|
# +-----------+-------------+------------+--------+-------+----------+---------+----------+-----------------+------------------+------------+
# only showing top 5 rows
#
# 4️⃣ Data Type Conversions:
#    Convert sale_date to proper date type
# +---------+----------+---------+----------+
# |  sale_id| sale_date|sale_year|sale_month|
# +---------+----------+---------+----------+
# |SALE_0001|2025-07-19|     2025|         7|
# |SALE_0002|2025-07-05|     2025|         7|
# |SALE_0003|2026-01-03|     2026|         1|
# |SALE_0004|2025-08-07|     2025|         8|
# |SALE_0005|2025-08-15|     2025|         8|
# +---------+----------+---------+----------+
# only showing top 5 rows
#
# ✅ Basic DataFrame operations completed!

# %% [markdown]
# ## Exercise 2: Aggregations and Grouping
#
# ### 🎯 **Learning Objectives:**
# - Master groupBy operations
# - Learn aggregation functions
# - Practice window functions
# - Understand data summarization patterns
#
# ### 📚 **Key Concepts:**
# 1. **GroupBy**: Grouping data by columns
# 2. **Aggregations**: Sum, count, avg, min, max operations
# 3. **Window Functions**: Advanced analytical functions
# 4. **Pivoting**: Reshaping data for analysis

# %%
# Exercise 2: Aggregations and Grouping
print("📊 Exercise 2: Aggregations and Grouping")

print("\n1️⃣ Basic Aggregations:")
print("   Calculate total sales by product")

product_sales = sales_df.groupBy("product_name").agg(
    sum("quantity").alias("total_quantity"),
    sum(col("quantity") * col("unit_price")).alias("total_revenue"),
    avg("unit_price").alias("avg_price"),
    count("*").alias("sale_count")
).orderBy(desc("total_revenue"))

product_sales.show()

print("\n2️⃣ Multi-level Grouping:")
print("   Sales by region and category")

region_category_sales = sales_df.groupBy("region", "category").agg(
    sum(col("quantity") * col("unit_price")).alias("total_revenue"),
    avg(col("quantity") * col("unit_price")).alias("avg_transaction_value"),
    count("*").alias("transaction_count")
).orderBy(desc("total_revenue"))

region_category_sales.show()

print("\n3️⃣ Window Functions:")
print("   Calculate running totals and rankings")

# Define window specification
window_spec = Window.partitionBy("customer_name").orderBy("sale_date")

# Add running totals and rankings
sales_with_window = sales_df.withColumn(
    "running_total", 
    sum(col("quantity") * col("unit_price")).over(window_spec)
).withColumn(
    "transaction_rank",
    row_number().over(window_spec)
).withColumn(
    "customer_avg_transaction",
    avg(col("quantity") * col("unit_price")).over(
        Window.partitionBy("customer_name")
    )
)

sales_with_window.select(
    "customer_name", "sale_date", "quantity", "unit_price", 
    "running_total", "transaction_rank", "customer_avg_transaction"
).show(10)

print("\n4️⃣ Pivot Operations:")
print("   Pivot sales data by region")

pivot_sales = sales_df.groupBy("product_name").pivot("region").agg(
    sum(col("quantity") * col("unit_price")).alias("revenue")
).fillna(0)

pivot_sales.show()

print("\n✅ Aggregations and grouping completed!")
# Out:
# 📊 Exercise 2: Aggregations and Grouping
#
# 1️⃣ Basic Aggregations:
#    Calculate total sales by product
# +------------+--------------+------------------+------------------+----------+
# |product_name|total_quantity|     total_revenue|         avg_price|sale_count|
# +------------+--------------+------------------+------------------+----------+
# |  Headphones|           451|468955.38000000006|1034.7528205128206|       156|
# |      Laptop|           420|         438943.56| 1065.148320610687|       131|
# |     Monitor|           390|         420675.84| 1074.706935483871|       124|
# |    Keyboard|           407|         394641.35|1029.6442537313433|       134|
# |      Tablet|           346|369260.57999999996| 1040.294778761062|       113|
# |       Mouse|           344|         355320.16|1018.3380188679246|       106|
# |      Camera|           339|         336272.62|1016.6661417322836|       127|
# |       Phone|           300|         305327.36|1000.8240366972477|       109|
# +------------+--------------+------------------+------------------+----------+
#
#
# 2️⃣ Multi-level Grouping:
#    Sales by region and category
# +-------+-----------+------------------+---------------------+-----------------+
# | region|   category|     total_revenue|avg_transaction_value|transaction_count|
# +-------+-----------+------------------+---------------------+-----------------+
# |  South|Electronics|         244714.14|    3352.248493150685|               73|
# |   East|  Computing|         238850.98|              3564.94|               67|
# |Central|Accessories|         236540.53|   2920.2534567901234|               81|
# |Central|Electronics|         234516.14|   3085.7386842105266|               76|
# |   East|Electronics|         232561.34|           2907.01675|               80|
# |  North|Electronics|         229838.37|        3591.22453125|               64|
# |  South|  Computing|         218592.22|    3214.591470588235|               68|
# |   East|Accessories|         213218.11|        3331.53296875|               64|
# |  North|  Computing|207976.22999999998|   2888.5587499999997|               72|
# |   West|  Computing|206952.97000000003|   2834.9721917808224|               73|
# |   West|Electronics|          200593.0|   3086.0461538461536|               65|
# |  North|Accessories|167514.66999999998|    2888.183965517241|               58|
# |   West|Accessories|159578.50999999998|    2704.720508474576|               59|
# |Central|  Computing|151362.12999999998|   2803.0024074074067|               54|
# |  South|Accessories|         146587.51|   3186.6850000000004|               46|
# +-------+-----------+------------------+---------------------+-----------------+
#
#
# 3️⃣ Window Functions:
#    Calculate running totals and rankings
# +-------------+----------+--------+----------+------------------+----------------+------------------------+
# |customer_name| sale_date|quantity|unit_price|     running_total|transaction_rank|customer_avg_transaction|
# +-------------+----------+--------+----------+------------------+----------------+------------------------+
# |        Alice|2025-04-08|       2|   1453.03|           2906.06|               1|       3266.978037383179|
# |        Alice|2025-04-13|       3|   1199.89|           6505.73|               2|       3266.978037383179|
# |        Alice|2025-04-16|       4|   1415.93|          16317.04|               3|       3266.978037383179|
# |        Alice|2025-04-16|       3|   1382.53|          16317.04|               4|       3266.978037383179|
# |        Alice|2025-04-21|       1|   1188.04|          17505.08|               5|       3266.978037383179|
# |        Alice|2025-04-24|       5|    1922.7|          27118.58|               6|       3266.978037383179|
# |        Alice|2025-04-27|       1|   1330.93|31487.070000000003|               7|       3266.978037383179|
# |        Alice|2025-04-27|       2|   1518.78|31487.070000000003|               8|       3266.978037383179|
# |        Alice|2025-04-29|       1|   1845.57| 33332.64000000001|               9|       3266.978037383179|
# |        Alice|2025-05-06|       4|   1168.68| 38007.36000000001|              10|       3266.978037383179|
# +-------------+----------+--------+----------+------------------+----------------+------------------------+
# only showing top 10 rows
#
# 4️⃣ Pivot Operations:
#    Pivot sales data by region
# +------------+------------------+------------------+------------------+------------------+------------------+
# |product_name|           Central|              East|             North|             South|              West|
# +------------+------------------+------------------+------------------+------------------+------------------+
# |       Phone| 62996.92000000001|          63786.22|          54727.17| 83667.14000000001|40149.909999999996|
# |      Laptop| 82501.24999999999|           97717.5| 87710.18999999999|          61220.55|         109794.07|
# |       Mouse| 79386.07999999999|          77773.51| 63846.80000000001|          70991.25|63322.520000000004|
# |      Camera| 61252.87000000001| 90292.65000000002|54145.939999999995|          66099.83| 64481.32999999999|
# |      Tablet|          64578.41|61781.149999999994| 72695.24999999999| 86055.56999999999|           84150.2|
# |    Keyboard|          74402.57|           96467.5| 98127.60000000002|64890.420000000006| 60753.26000000001|
# |     Monitor|119081.09000000001|          84040.94| 63335.27999999999|          85016.28|          69202.25|
# |  Headphones| 78219.60999999999|         112770.96|         110741.04| 91952.82999999999|          75270.94|
# +------------+------------------+------------------+------------------+------------------+------------------+
#
#
# ✅ Aggregations and grouping completed!

# %% [markdown]
# ## Exercise 3: Joins and Data Integration
#
# ### 🎯 **Learning Objectives:**
# - Master different join types
# - Learn data integration patterns
# - Practice complex join operations
# - Understand join optimization
#
# ### 📚 **Key Concepts:**
# 1. **Inner Join**: Matching records from both tables
# 2. **Left/Right Join**: Including all records from one side
# 3. **Outer Join**: Including all records from both sides
# 4. **Join Optimization**: Efficient join strategies

# %%
# Exercise 3: Joins and Data Integration
print("🔗 Exercise 3: Joins and Data Integration")

print("\n1️⃣ Inner Join:")
print("   Join sales with customer data")

sales_customers = sales_df.join(
    customers_df, 
    sales_df.customer_name == customers_df.customer_name, 
    "inner"
).select(
    sales_df["*"],
    customers_df.age.alias("customer_age"),
    customers_df.city.alias("customer_city"),
    customers_df.membership_level.alias("customer_membership")
)

print(f"   📊 Joined records: {sales_customers.count()}")
sales_customers.show(5)

print("\n2️⃣ Left Join:")
print("   Join sales with product data (include all sales)")

sales_products = sales_df.join(
    products_df,
    sales_df.product_name == products_df.product_name,
    "left"
).select(
    sales_df["*"],
    products_df.brand.alias("product_brand"),
    products_df.cost_price.alias("product_cost"),
    products_df.in_stock.alias("current_stock")
)

print(f"   📊 Joined records: {sales_products.count()}")
sales_products.show(5)

print("\n3️⃣ Complex Multi-table Join:")
print("   Join sales, customers, and products")

complete_sales = sales_df.join(
    customers_df,
    sales_df.customer_name == customers_df.customer_name,
    "inner"
).join(
    products_df,
    sales_df.product_name == products_df.product_name,
    "inner"
).select(
    sales_df.sale_id,
    sales_df.customer_name,
    sales_df.product_name,
    sales_df.quantity,
    sales_df.unit_price,
    (sales_df.quantity * sales_df.unit_price).alias("total_amount"),
    customers_df.age,
    customers_df.city,
    customers_df.membership_level,
    products_df.brand,
    products_df.cost_price,
    (sales_df.quantity * sales_df.unit_price - sales_df.quantity * products_df.cost_price).alias("profit")
)

print(f"   📊 Complete joined records: {complete_sales.count()}")
complete_sales.show(5)

print("\n4️⃣ Join Analysis:")
print("   Analyze profit by customer membership level")

profit_by_membership = complete_sales.groupBy("membership_level").agg(
    sum("total_amount").alias("total_revenue"),
    sum("profit").alias("total_profit"),
    avg("profit").alias("avg_profit_per_transaction"),
    count("*").alias("transaction_count")
).orderBy(desc("total_profit"))

profit_by_membership.show()

print("\n✅ Joins and data integration completed!")
# Out:
# 🔗 Exercise 3: Joins and Data Integration
#
# 1️⃣ Inner Join:
#    Join sales with customer data
#    📊 Joined records: 1000
# +-----------+-------------+------------+--------+-------+----------+---------+----------+------------+-------------+-------------------+
# |   category|customer_name|product_name|quantity| region| sale_date|  sale_id|unit_price|customer_age|customer_city|customer_membership|
# +-----------+-------------+------------+--------+-------+----------+---------+----------+------------+-------------+-------------------+
# |  Computing|        Alice|  Headphones|       1|  South|2025-07-19|SALE_0001|   1932.68|          39|      Chicago|             Bronze|
# |Electronics|        Alice|     Monitor|       5|  South|2025-10-16|SALE_0013|    1009.4|          39|      Chicago|             Bronze|
# |  Computing|        Alice|       Phone|       1|  North|2025-12-10|SALE_0027|   1431.15|          39|      Chicago|             Bronze|
# |Accessories|        Alice|      Laptop|       4|Central|2025-12-21|SALE_0033|    924.67|          39|      Chicago|             Bronze|
# |Accessories|        Alice|       Mouse|       4|  South|2025-05-06|SALE_0034|   1168.68|          39|      Chicago|             Bronze|
# +-----------+-------------+------------+--------+-------+----------+---------+----------+------------+-------------+-------------------+
# only showing top 5 rows
#
# 2️⃣ Left Join:
#    Join sales with product data (include all sales)
#    📊 Joined records: 1000
# +-----------+-------------+------------+--------+-------+----------+---------+----------+-------------+------------+-------------+
# |   category|customer_name|product_name|quantity| region| sale_date|  sale_id|unit_price|product_brand|product_cost|current_stock|
# +-----------+-------------+------------+--------+-------+----------+---------+----------+-------------+------------+-------------+
# |  Computing|          Eve|      Camera|       4|  South|2025-08-07|SALE_0004|   1762.18|   DigitalPro|      418.75|            2|
# |Electronics|          Bob|      Camera|       3|   East|2025-08-15|SALE_0005|    193.67|   DigitalPro|      418.75|            2|
# |Accessories|          Eve|      Tablet|       2|Central|2026-01-03|SALE_0003|    762.13|    SmartTech|      893.81|           36|
# |Accessories|        Diana|    Keyboard|       2|Central|2025-09-11|SALE_0006|   1505.43|    SmartTech|     1217.58|           92|
# |Electronics|        Frank|     Monitor|       5|Central|2025-07-05|SALE_0002|   1136.68|     TechCorp|      977.96|           41|
# +-----------+-------------+------------+--------+-------+----------+---------+----------+-------------+------------+-------------+
# only showing top 5 rows
#
# 3️⃣ Complex Multi-table Join:
#    Join sales, customers, and products
#    📊 Complete joined records: 1000
# +---------+-------------+------------+--------+----------+------------+---+-------+----------------+----------+----------+------------------+
# |  sale_id|customer_name|product_name|quantity|unit_price|total_amount|age|   city|membership_level|     brand|cost_price|            profit|
# +---------+-------------+------------+--------+----------+------------+---+-------+----------------+----------+----------+------------------+
# |SALE_0070|        Alice|      Camera|       2|   1685.95|      3371.9| 39|Chicago|          Bronze|DigitalPro|    418.75|            2534.4|
# |SALE_0148|        Alice|      Camera|       1|   1330.93|     1330.93| 39|Chicago|          Bronze|DigitalPro|    418.75| 912.1800000000001|
# |SALE_0204|        Alice|      Camera|       1|   1999.54|     1999.54| 39|Chicago|          Bronze|DigitalPro|    418.75|           1580.79|
# |SALE_0251|        Alice|      Camera|       2|   1483.49|     2966.98| 39|Chicago|          Bronze|DigitalPro|    418.75|           2129.48|
# |SALE_0453|        Alice|      Camera|       2|   1201.88|     2403.76| 39|Chicago|          Bronze|DigitalPro|    418.75|1566.2600000000002|
# +---------+-------------+------------+--------+----------+------------+---+-------+----------------+----------+----------+------------------+
# only showing top 5 rows
#
# 4️⃣ Join Analysis:
#    Analyze profit by customer membership level
# [Stage 98:=====================>                                    (3 + 5) / 8]
# +----------------+-----------------+------------------+--------------------------+-----------------+
# |membership_level|    total_revenue|      total_profit|avg_profit_per_transaction|transaction_count|
# +----------------+-----------------+------------------+--------------------------+-----------------+
# |          Bronze|1430494.060000001| 184493.1800000001|         385.1632150313155|              479|
# |        Platinum|        776377.34|145717.37999999995|         569.2085156249998|              256|
# |            Gold|        428877.17|          81199.54|         639.3664566929133|              127|
# |          Silver|        453648.28| 72123.61000000002|         522.6348550724639|              138|
# +----------------+-----------------+------------------+--------------------------+-----------------+
#
#
# ✅ Joins and data integration completed!

# %% [markdown]
# ## Exercise 4: Performance Optimization
#
# ### 🎯 **Learning Objectives:**
# - Learn DataFrame caching strategies
# - Understand partitioning concepts
# - Practice performance monitoring
# - Master optimization techniques
#
# ### 📚 **Key Concepts:**
# 1. **Caching**: Storing DataFrames in memory
# 2. **Partitioning**: Data distribution strategies
# 3. **Broadcast Joins**: Optimizing small table joins
# 4. **Performance Monitoring**: Tracking execution metrics

# %%
# Exercise 4: Performance Optimization
print("⚡ Exercise 4: Performance Optimization")

print("\n1️⃣ DataFrame Caching:")
print("   Cache frequently used DataFrames")

# Cache the complete sales DataFrame for multiple operations
complete_sales.cache()
print("   📊 Cached complete_sales DataFrame")

# Test cache performance
import time
start_time = time.time()
count1 = complete_sales.count()
first_run_time = time.time() - start_time

start_time = time.time()
count2 = complete_sales.count()
second_run_time = time.time() - start_time

print(f"   ⏱️ First count: {first_run_time:.3f}s")
print(f"   ⏱️ Second count: {second_run_time:.3f}s")
print(f"   📊 Records: {count1}")

print("\n2️⃣ Broadcast Join:")
print("   Use broadcast join for small tables")

# Broadcast the small customers table
from pyspark.sql.functions import broadcast

sales_broadcast = sales_df.join(
    broadcast(customers_df),
    sales_df.customer_name == customers_df.customer_name,
    "inner"
)

print("   📊 Used broadcast join for customers table")
sales_broadcast.select("sale_id", sales_df.customer_name, "age", "city").show(5)

print("\n3️⃣ Repartitioning:")
print("   Optimize data partitioning")

# Check current partitions
print(f"   📊 Current partitions: {sales_df.rdd.getNumPartitions()}")

# Repartition by region for better performance
sales_repartitioned = sales_df.repartition(4, "region")
print(f"   📊 Repartitioned partitions: {sales_repartitioned.rdd.getNumPartitions()}")

# Coalesce to reduce partitions
sales_coalesced = sales_repartitioned.coalesce(2)
print(f"   📊 Coalesced partitions: {sales_coalesced.rdd.getNumPartitions()}")

print("\n4️⃣ Performance Monitoring:")
print("   Monitor Spark application performance")

# Get Spark context information
sc = spark.sparkContext
print(f"   🔧 Spark Version: {sc.version}")
print(f"   🔧 Master: {sc.master}")
print(f"   🔧 App Name: {sc.appName}")

print("\n5️⃣ Memory Management:")
print("   Check DataFrame memory usage")

# Show storage level
print(f"   📊 Storage Level: {complete_sales.storageLevel}")

# Unpersist cached DataFrames
complete_sales.unpersist()
print("   🗑️ Unpersisted cached DataFrame")

print("\n✅ Performance optimization completed!")
# Out:
# ⚡ Exercise 4: Performance Optimization
#
# 1️⃣ DataFrame Caching:
#    Cache frequently used DataFrames
#    📊 Cached complete_sales DataFrame
# 26/04/06 21:43:09 WARN CacheManager: Asked to cache already cached data.
#    ⏱️ First count: 0.363s
#    ⏱️ Second count: 0.326s
#    📊 Records: 1000
#
# 2️⃣ Broadcast Join:
#    Use broadcast join for small tables
#    📊 Used broadcast join for customers table
# +---------+-------------+---+-------+
# |  sale_id|customer_name|age|   city|
# +---------+-------------+---+-------+
# |SALE_0001|        Alice| 39|Chicago|
# |SALE_0002|        Frank| 46|Houston|
# |SALE_0003|          Eve| 40|Houston|
# |SALE_0004|          Eve| 40|Houston|
# |SALE_0005|          Bob| 28|Houston|
# +---------+-------------+---+-------+
# only showing top 5 rows
#
# 3️⃣ Repartitioning:
#    Optimize data partitioning
#    📊 Current partitions: 8
#    📊 Repartitioned partitions: 4
#    📊 Coalesced partitions: 2
#
# 4️⃣ Performance Monitoring:
#    Monitor Spark application performance
#    🔧 Spark Version: 4.1.1
#    🔧 Master: local[*]
#    🔧 App Name: SparkBatchProcessingLab
#
# 5️⃣ Memory Management:
#    Check DataFrame memory usage
#    📊 Storage Level: Disk Memory Deserialized 1x Replicated
#    🗑️ Unpersisted cached DataFrame
#
# ✅ Performance optimization completed!

# %% [markdown]
# ## Exercise 5: Data Persistence and Export
#
# ### 🎯 **Learning Objectives:**
# - Learn data persistence strategies
# - Practice different file formats
# - Understand data export patterns
# - Master data pipeline completion
#
# ### 📚 **Key Concepts:**
# 1. **File Formats**: Parquet, JSON, CSV, Avro
# 2. **Data Persistence**: Saving processed results
# 3. **Partitioned Storage**: Organizing data by partitions
# 4. **Data Export**: Writing to external systems

# %%
# Exercise 5: Data Persistence and Export
print("💾 Exercise 5: Data Persistence and Export")

print("\n1️⃣ Export to Different Formats:")
print("   Save processed data in various formats")

# Create output directory
output_dir = "/tmp/spark_lab_output"
print(f"   📁 Output directory: {output_dir}")

# Export to Parquet (recommended for Spark)
print("\n   📊 Exporting to Parquet format...")
complete_sales.write \
    .mode("overwrite") \
    .parquet(f"{output_dir}/sales_parquet")

print("   ✅ Parquet export completed")

# Export to JSON
print("\n   📊 Exporting to JSON format...")
product_sales.write \
    .mode("overwrite") \
    .json(f"{output_dir}/product_sales_json")

print("   ✅ JSON export completed")

# Export to CSV
print("\n   📊 Exporting to CSV format...")
profit_by_membership.write \
    .mode("overwrite") \
    .option("header", "true") \
    .csv(f"{output_dir}/profit_analysis_csv")

print("   ✅ CSV export completed")

print("\n2️⃣ Partitioned Storage:")
print("   Save data partitioned by region")

# Partition by region for better query performance
print("\n   📊 Exporting partitioned data...")
sales_df.write \
    .mode("overwrite") \
    .partitionBy("region") \
    .parquet(f"{output_dir}/sales_partitioned")

print("   ✅ Partitioned export completed")

print("\n3️⃣ Data Validation:")
print("   Verify exported data")

# Read back and validate
print("\n   📊 Reading Parquet data...")
parquet_data = spark.read.parquet(f"{output_dir}/sales_parquet")
print(f"   📊 Parquet records: {parquet_data.count()}")

print("\n   📊 Reading JSON data...")
json_data = spark.read.json(f"{output_dir}/product_sales_json")
print(f"   📊 JSON records: {json_data.count()}")

print("\n   📊 Reading CSV data...")
csv_data = spark.read.option("header", "true").csv(f"{output_dir}/profit_analysis_csv")
print(f"   📊 CSV records: {csv_data.count()}")

print("\n4️⃣ Summary Statistics:")
print("   Final data processing summary")

print(f"\n📊 Processing Summary:")
print(f"   📈 Total sales records processed: {sales_df.count()}")
print(f"   👥 Customer records: {customers_df.count()}")
print(f"   📦 Product records: {products_df.count()}")
print(f"   🔗 Joined records: {complete_sales.count()}")
print(f"   📊 Product sales analysis: {product_sales.count()}")
print(f"   💰 Profit analysis records: {profit_by_membership.count()}")

print("\n✅ Data persistence and export completed!")
print("🎉 Spark Batch Processing Lab completed successfully!")
# Out:
# 💾 Exercise 5: Data Persistence and Export
#
# 1️⃣ Export to Different Formats:
#    Save processed data in various formats
#    📁 Output directory: /tmp/spark_lab_output
#
#    📊 Exporting to Parquet format...
#    ✅ Parquet export completed
#
#    📊 Exporting to JSON format...
#    ✅ JSON export completed
#
#    📊 Exporting to CSV format...
#    ✅ CSV export completed
#
# 2️⃣ Partitioned Storage:
#    Save data partitioned by region
#
#    📊 Exporting partitioned data...
#    ✅ Partitioned export completed
#
# 3️⃣ Data Validation:
#    Verify exported data
#
#    📊 Reading Parquet data...
#    📊 Parquet records: 1000
#
#    📊 Reading JSON data...
#    📊 JSON records: 8
#
#    📊 Reading CSV data...
#    📊 CSV records: 4
#
# 4️⃣ Summary Statistics:
#    Final data processing summary
#
# 📊 Processing Summary:
#    📈 Total sales records processed: 1000
#    👥 Customer records: 8
#    📦 Product records: 8
#    🔗 Joined records: 1000
#    📊 Product sales analysis: 8
#    💰 Profit analysis records: 4
#
# ✅ Data persistence and export completed!
# 🎉 Spark Batch Processing Lab completed successfully!

# %%
# Cleanup and Best Practices
print("🧹 Cleanup and Best Practices")

print("\n📋 Spark Batch Processing Best Practices:")
print("✅ Use appropriate file formats (Parquet for analytics)")
print("✅ Cache DataFrames that are used multiple times")
print("✅ Use broadcast joins for small tables")
print("✅ Partition data by frequently queried columns")
print("✅ Monitor Spark UI for performance insights")
print("✅ Use appropriate data types to save memory")
print("✅ Avoid unnecessary shuffles and repartitions")
print("✅ Use column pruning and predicate pushdown")
print("✅ Set appropriate batch sizes for streaming")
print("✅ Clean up cached DataFrames when done")

print("\n🔧 Performance Tips:")
print("✅ Enable adaptive query execution (AQE)")
print("✅ Use Kryo serializer for better performance")
print("✅ Tune executor memory and cores")
print("✅ Use appropriate storage levels")
print("✅ Monitor and optimize shuffle operations")

print("\n📊 Data Quality Tips:")
print("✅ Validate data schemas")
print("✅ Handle null values appropriately")
print("✅ Use consistent data types")
print("✅ Implement data quality checks")
print("✅ Document data transformations")

print("\n🎯 Next Steps:")
print("🚀 Try Lab 2: Spark Streaming for real-time processing")
print("🤖 Try Lab 3: Spark MLlib for machine learning")
print("📈 Explore Spark UI for performance monitoring")
print("🔍 Practice with larger datasets")

print("\n✅ Spark Batch Processing Lab completed!")
print("🎉 Ready for Spark Streaming and MLlib labs!")
# Out:
# 🧹 Cleanup and Best Practices
#
# 📋 Spark Batch Processing Best Practices:
# ✅ Use appropriate file formats (Parquet for analytics)
# ✅ Cache DataFrames that are used multiple times
# ✅ Use broadcast joins for small tables
# ✅ Partition data by frequently queried columns
# ✅ Monitor Spark UI for performance insights
# ✅ Use appropriate data types to save memory
# ✅ Avoid unnecessary shuffles and repartitions
# ✅ Use column pruning and predicate pushdown
# ✅ Set appropriate batch sizes for streaming
# ✅ Clean up cached DataFrames when done
#
# 🔧 Performance Tips:
# ✅ Enable adaptive query execution (AQE)
# ✅ Use Kryo serializer for better performance
# ✅ Tune executor memory and cores
# ✅ Use appropriate storage levels
# ✅ Monitor and optimize shuffle operations
#
# 📊 Data Quality Tips:
# ✅ Validate data schemas
# ✅ Handle null values appropriately
# ✅ Use consistent data types
# ✅ Implement data quality checks
# ✅ Document data transformations
#
# 🎯 Next Steps:
# 🚀 Try Lab 2: Spark Streaming for real-time processing
# 🤖 Try Lab 3: Spark MLlib for machine learning
# 📈 Explore Spark UI for performance monitoring
# 🔍 Practice with larger datasets
#
# ✅ Spark Batch Processing Lab completed!
# 🎉 Ready for Spark Streaming and MLlib labs!
