# %% [markdown]
# # Lab 5: Real-time Stock Analytics with Kafka
#
# ## 🎯 **Learning Objectives:**
# - Build real-time stock analytics pipeline
# - Implement multiple consumer groups for different analytics
# - Practice stream processing patterns
# - Create real-time dashboards and monitoring
# - Handle high-throughput data streams
# - Learn about Kafka Streams concepts
#
# ## 📚 **Key Concepts:**
# 1. **Real-time Analytics**: Processing data as it arrives
# 2. **Multiple Consumer Groups**: Different processing pipelines
# 3. **Stream Processing**: Continuous data processing patterns
# 4. **Real-time Dashboards**: Live data visualization
# 5. **High-throughput Processing**: Handling large data volumes
# 6. **Alert Systems**: Real-time notifications and triggers
#
# ## 🏗️ **Architecture Overview:**
# ```
# ┌─────────────────┐    ┌──────────────────┐    ┌─────────────────┐
# │   Stock Data    │───▶│   Kafka Topic    │───▶│   Analytics     │
# │   Producer      │    │   (3 Partitions) │    │   Consumer      │
# │                 │    │                  │    │   Groups        │
# └─────────────────┘    └──────────────────┘    └─────────────────┘
#          │                        │                        │
#          ▼                        ▼                        ▼
# ┌─────────────────┐    ┌──────────────────┐    ┌─────────────────┐
# │ High-frequency  │    │ Partition 0      │    │ Analytics      │
# │ Data Generation │    │ Partition 1      │    │ • Moving Avg   │
# │                 │    │ Partition 2      │    │ • Price Alerts │
# │                 │    │                  │    │ • Volume       │
# └─────────────────┘    └──────────────────┘    └─────────────────┘
#                                 │                        │
#                                 ▼                        ▼
#                        ┌─────────────────┐    ┌─────────────────┐
#                        │ Storage Group   │    │ Dashboard Group │
#                        │ • PostgreSQL    │    │ • Real-time UI  │
#                        │ • Redis Cache   │    │ • Charts        │
#                        └─────────────────┘    └─────────────────┘
# ```

# %%
# Install and Import Dependencies
import json
import random
import time
import threading
from datetime import datetime, timedelta
from collections import defaultdict, deque
from kafka import KafkaProducer, KafkaConsumer, KafkaAdminClient
from kafka.errors import KafkaError
from kafka.admin import NewTopic
import uuid
import statistics

print("✅ All dependencies imported successfully!")
# Out:
# ✅ All dependencies imported successfully!

# %%
# Kafka Configuration for Real-time Analytics
KAFKA_BOOTSTRAP_SERVERS = 'localhost:9092'
TOPIC_NAME = 'stock-analytics-lab5'
CONSUMER_GROUPS = {
    'analytics': 'stock-analytics-group',
    'alerts': 'stock-alerts-group', 
    'storage': 'stock-storage-group',
    'dashboard': 'stock-dashboard-group'
}

# Analytics Configuration
ANALYTICS_CONFIG = {
    'moving_average_window': 10,
    'price_alert_threshold': 0.05,  # 5% price change
    'volume_alert_threshold': 2.0,  # 2x average volume
    'trend_detection_window': 5,
    'high_frequency_interval': 0.1  # 100ms between messages
}

print("🔧 Real-time Analytics Configuration:")
print(f"   Bootstrap Servers: {KAFKA_BOOTSTRAP_SERVERS}")
print(f"   Topic: {TOPIC_NAME}")
print(f"   Consumer Groups: {list(CONSUMER_GROUPS.keys())}")
print(f"   Analytics Window: {ANALYTICS_CONFIG['moving_average_window']} messages")
print(f"   Price Alert Threshold: {ANALYTICS_CONFIG['price_alert_threshold']*100}%")
print(f"   High-frequency Interval: {ANALYTICS_CONFIG['high_frequency_interval']}s")
# Out:
# 🔧 Real-time Analytics Configuration:
#    Bootstrap Servers: localhost:9092
#    Topic: stock-analytics-lab5
#    Consumer Groups: ['analytics', 'alerts', 'storage', 'dashboard']
#    Analytics Window: 10 messages
#    Price Alert Threshold: 5.0%
#    High-frequency Interval: 0.1s

# %%
# Create Topic for Real-time Analytics Lab
def create_analytics_topic(topic_name: str, num_partitions: int = 3):
    """Create topic for real-time analytics"""
    try:
        admin_client = KafkaAdminClient(
            bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS,
            client_id='analytics_lab_admin'
        )
        
        # Check if topic exists
        metadata = admin_client.describe_cluster()
        print(f"✅ Connected to Kafka cluster")
        
        try:
            topic_metadata = admin_client.describe_topics([topic_name])
            topic_info = topic_metadata[topic_name]
            existing_partitions = len(topic_info.partitions)
            
            if existing_partitions == num_partitions:
                print(f"✅ Topic '{topic_name}' already exists with {num_partitions} partitions")
            else:
                print(f"⚠️ Topic '{topic_name}' exists but has {existing_partitions} partitions, need {num_partitions}")
                print(f"🔄 Deleting and recreating topic...")
                
                admin_client.delete_topics([topic_name])
                time.sleep(2)
                
                topic = NewTopic(
                    name=topic_name,
                    num_partitions=num_partitions,
                    replication_factor=1
                )
                admin_client.create_topics([topic])
                print(f"✅ Topic '{topic_name}' recreated with {num_partitions} partitions")
                
        except Exception as e:
            print(f"📝 Creating topic '{topic_name}' with {num_partitions} partitions...")
            topic = NewTopic(
                name=topic_name,
                num_partitions=num_partitions,
                replication_factor=1
            )
            admin_client.create_topics([topic])
            print(f"✅ Topic '{topic_name}' created successfully")
        
        admin_client.close()
        
    except Exception as e:
        print(f"❌ Error managing topic: {e}")
        print("💡 Make sure Kafka is running: docker-compose up -d")

# Create the analytics topic
create_analytics_topic(TOPIC_NAME, 3)
# Out:
# ✅ Connected to Kafka cluster
# 📝 Creating topic 'stock-analytics-lab5' with 3 partitions...
# ✅ Topic 'stock-analytics-lab5' created successfully

# %%
# High-Frequency Stock Data Producer
class HighFrequencyStockProducer:
    """Producer for high-frequency stock data simulation"""
    
    def __init__(self, bootstrap_servers: str, topic: str):
        self.topic = topic
        self.symbols = ['AAPL', 'GOOGL', 'MSFT', 'TSLA', 'AMZN', 'META', 'NVDA', 'NFLX', 'ADBE', 'CRM']
        self.base_prices = {
            'AAPL': 150.0, 'GOOGL': 2800.0, 'MSFT': 350.0, 'TSLA': 250.0, 'AMZN': 3200.0,
            'META': 300.0, 'NVDA': 450.0, 'NFLX': 400.0, 'ADBE': 500.0, 'CRM': 200.0
        }
        self.current_prices = self.base_prices.copy()
        self.message_count = 0
        
    def generate_realistic_price(self, symbol: str) -> float:
        """Generate realistic price movement using random walk"""
        current_price = self.current_prices[symbol]
        
        # Random walk with slight upward bias
        change_percent = random.gauss(0.0001, 0.01)  # 0.01% volatility
        new_price = current_price * (1 + change_percent)
        
        # Ensure price stays positive and realistic
        new_price = max(new_price, current_price * 0.95)  # Max 5% drop
        new_price = min(new_price, current_price * 1.05)  # Max 5% gain
        
        self.current_prices[symbol] = new_price
        return round(new_price, 2)
    
    def generate_ohlcv_data(self, symbol: str) -> dict:
        """Generate realistic OHLCV data"""
        close_price = self.generate_realistic_price(symbol)
        
        # Generate OHLC around close price
        volatility = 0.002  # 0.2% intraday volatility
        open_price = round(close_price * random.uniform(1 - volatility, 1 + volatility), 2)
        high_price = round(max(open_price, close_price) * random.uniform(1.001, 1.005), 2)
        low_price = round(min(open_price, close_price) * random.uniform(0.995, 0.999), 2)
        
        # Volume with some randomness
        base_volume = random.randint(50000, 500000)
        volume_multiplier = random.uniform(0.5, 2.0)
        volume = int(base_volume * volume_multiplier)
        
        self.message_count += 1
        
        return {
            "symbol": symbol,
            "timestamp": datetime.now().isoformat() + "Z",
            "open": open_price,
            "high": high_price,
            "low": low_price,
            "close": close_price,
            "volume": volume,
            "exchange": "NASDAQ",
            "message_id": str(uuid.uuid4()),
            "sequence_number": self.message_count
        }
    
    def start_high_frequency_stream(self, duration_seconds: int = 30, interval: float = 0.1):
        """Start high-frequency data stream"""
        print(f"🚀 Starting high-frequency stream for {duration_seconds} seconds...")
        print(f"   Interval: {interval}s between messages")
        print(f"   Expected messages: ~{int(duration_seconds / interval)}")
        
        producer_config = {
            'bootstrap_servers': KAFKA_BOOTSTRAP_SERVERS,
            'value_serializer': lambda v: json.dumps(v).encode('utf-8'),
            'key_serializer': lambda k: k.encode('utf-8') if k else None,
            'acks': 'all',
            'retries': 3,
            'retry_backoff_ms': 100,
            'batch_size': 16384,
            'linger_ms': 5,  # Batch messages for 5ms
            'compression_type': 'gzip'
        }
        
        producer = KafkaProducer(**producer_config)
        start_time = time.time()
        messages_sent = 0
        
        try:
            while time.time() - start_time < duration_seconds:
                symbol = random.choice(self.symbols)
                ohlcv_data = self.generate_ohlcv_data(symbol)
                
                # Send message
                future = producer.send(
                    self.topic,
                    key=symbol,
                    value=ohlcv_data
                )
                
                try:
                    record_metadata = future.get(timeout=1)
                    messages_sent += 1
                    
                    if messages_sent % 50 == 0:  # Print every 50 messages
                        print(f"📊 Sent {messages_sent} messages - Latest: {symbol} ${ohlcv_data['close']}")
                    
                except KafkaError as e:
                    print(f"❌ Error sending message: {e}")
                
                time.sleep(interval)
                
        except KeyboardInterrupt:
            print("\n⏹️ Stream stopped by user")
        finally:
            producer.flush()
            producer.close()
            
        print(f"✅ High-frequency stream completed!")
        print(f"   Total messages sent: {messages_sent}")
        print(f"   Average rate: {messages_sent / duration_seconds:.1f} messages/second")

# Initialize producer
producer = HighFrequencyStockProducer(KAFKA_BOOTSTRAP_SERVERS, TOPIC_NAME)
print("✅ High-Frequency Stock Producer initialized!")
# Out:
# ✅ High-Frequency Stock Producer initialized!

# %%
# Real-time Analytics Consumer Classes
class RealTimeAnalyticsConsumer:
    """Base class for real-time analytics consumers"""
    
    def __init__(self, bootstrap_servers: str, topic: str, group_id: str):
        self.bootstrap_servers = bootstrap_servers
        self.topic = topic
        self.group_id = group_id
        self.consumer = None
        self.processed_count = 0
        self.start_time = None
        
    def create_consumer(self, **kwargs):
        """Create consumer with optimized configuration for real-time processing"""
        default_config = {
            'bootstrap_servers': self.bootstrap_servers,
            'group_id': self.group_id,
            'value_deserializer': lambda m: json.loads(m.decode('utf-8')),
            'key_deserializer': lambda m: m.decode('utf-8') if m else None,
            # Changed from 'latest' to 'earliest' so when running notebooks sequentially, 
            # consumers can still read the data produced by the previous producer cell.
            'auto_offset_reset': 'earliest',
            'enable_auto_commit': True,
            'auto_commit_interval_ms': 1000,
            'session_timeout_ms': 30000,
            'heartbeat_interval_ms': 10000,
            'consumer_timeout_ms': 1000,
            'fetch_min_bytes': 1,
            'fetch_max_wait_ms': 100,
            'max_poll_records': 100
        }
        
        config = {**default_config, **kwargs}
        self.consumer = KafkaConsumer(self.topic, **config)
        return self.consumer
    
    def process_message(self, message):
        """Process a single message - override in subclasses"""
        data = message.value
        self.processed_count += 1
        
        if self.start_time is None:
            self.start_time = time.time()
        
        return data
    
    def get_processing_rate(self):
        """Get current processing rate"""
        if self.start_time is None:
            return 0
        elapsed = time.time() - self.start_time
        return self.processed_count / elapsed if elapsed > 0 else 0

class AnalyticsConsumer(RealTimeAnalyticsConsumer):
    """Consumer for real-time analytics calculations"""
    
    def __init__(self, bootstrap_servers: str, topic: str, group_id: str):
        super().__init__(bootstrap_servers, topic, group_id)
        self.price_history = defaultdict(lambda: deque(maxlen=ANALYTICS_CONFIG['moving_average_window']))
        self.volume_history = defaultdict(lambda: deque(maxlen=ANALYTICS_CONFIG['moving_average_window']))
        self.analytics_results = []
    
    def calculate_moving_average(self, symbol: str, prices: deque) -> float:
        """Calculate simple moving average"""
        if len(prices) < 2:
            return prices[-1] if prices else 0
        return statistics.mean(prices)
    
    def detect_trend(self, symbol: str, prices: deque) -> str:
        """Detect price trend"""
        if len(prices) < ANALYTICS_CONFIG['trend_detection_window']:
            return "insufficient_data"
        
        recent_prices = list(prices)[-ANALYTICS_CONFIG['trend_detection_window']:]
        first_price = recent_prices[0]
        last_price = recent_prices[-1]
        
        change_percent = (last_price - first_price) / first_price
        
        if change_percent > 0.02:  # 2% increase
            return "uptrend"
        elif change_percent < -0.02:  # 2% decrease
            return "downtrend"
        else:
            return "sideways"
    
    def process_message(self, message):
        """Process message and calculate analytics"""
        data = super().process_message(message)
        symbol = data['symbol']
        close_price = data['close']
        volume = data['volume']
        
        # Update history
        self.price_history[symbol].append(close_price)
        self.volume_history[symbol].append(volume)
        
        # Calculate analytics
        moving_avg = self.calculate_moving_average(symbol, self.price_history[symbol])
        trend = self.detect_trend(symbol, self.price_history[symbol])
        avg_volume = statistics.mean(self.volume_history[symbol]) if self.volume_history[symbol] else volume
        
        analytics_result = {
            'symbol': symbol,
            'timestamp': data['timestamp'],
            'close_price': close_price,
            'moving_average': round(moving_avg, 2),
            'trend': trend,
            'volume': volume,
            'avg_volume': round(avg_volume, 0),
            'volume_ratio': round(volume / avg_volume, 2) if avg_volume > 0 else 1.0,
            'message_id': data['message_id'],
            'sequence_number': data['sequence_number']
        }
        
        self.analytics_results.append(analytics_result)
        
        # Print analytics every 10 messages
        if self.processed_count % 10 == 0:
            print(f"📈 Analytics: {symbol} ${close_price} | MA: ${moving_avg:.2f} | Trend: {trend} | Vol: {volume:,}")
        
        return analytics_result

class AlertConsumer(RealTimeAnalyticsConsumer):
    """Consumer for price and volume alerts"""
    
    def __init__(self, bootstrap_servers: str, topic: str, group_id: str):
        super().__init__(bootstrap_servers, topic, group_id)
        self.price_alerts = []
        self.volume_alerts = []
        self.symbol_previous_prices = {}
    
    def check_price_alert(self, symbol: str, current_price: float) -> bool:
        """Check for significant price changes"""
        if symbol not in self.symbol_previous_prices:
            self.symbol_previous_prices[symbol] = current_price
            return False
        
        previous_price = self.symbol_previous_prices[symbol]
        change_percent = abs(current_price - previous_price) / previous_price
        
        if change_percent >= ANALYTICS_CONFIG['price_alert_threshold']:
            alert = {
                'symbol': symbol,
                'timestamp': datetime.now().isoformat(),
                'previous_price': previous_price,
                'current_price': current_price,
                'change_percent': round(change_percent * 100, 2),
                'alert_type': 'price_change'
            }
            self.price_alerts.append(alert)
            self.symbol_previous_prices[symbol] = current_price
            return True
        
        return False
    
    def check_volume_alert(self, symbol: str, volume: float, avg_volume: float) -> bool:
        """Check for unusual volume spikes"""
        if avg_volume <= 0:
            return False
        
        volume_ratio = volume / avg_volume
        
        if volume_ratio >= ANALYTICS_CONFIG['volume_alert_threshold']:
            alert = {
                'symbol': symbol,
                'timestamp': datetime.now().isoformat(),
                'volume': volume,
                'avg_volume': avg_volume,
                'volume_ratio': round(volume_ratio, 2),
                'alert_type': 'volume_spike'
            }
            self.volume_alerts.append(alert)
            return True
        
        return False
    
    def process_message(self, message):
        """Process message and check for alerts"""
        data = super().process_message(message)
        symbol = data['symbol']
        close_price = data['close']
        volume = data['volume']
        
        # Check price alert
        price_alert = self.check_price_alert(symbol, close_price)
        if price_alert:
            alert = self.price_alerts[-1]
            print(f"🚨 PRICE ALERT: {symbol} changed {alert['change_percent']}% from ${alert['previous_price']} to ${alert['current_price']}")
        
        # Check volume alert (simplified - would need historical data in real implementation)
        volume_alert = self.check_volume_alert(symbol, volume, volume * 0.5)  # Simplified
        if volume_alert:
            alert = self.volume_alerts[-1]
            print(f"📊 VOLUME ALERT: {symbol} volume {alert['volume_ratio']}x average ({alert['volume']:,} vs {alert['avg_volume']:,.0f})")
        
        return data

class DashboardConsumer(RealTimeAnalyticsConsumer):
    """Consumer for real-time dashboard updates"""
    
    def __init__(self, bootstrap_servers: str, topic: str, group_id: str):
        super().__init__(bootstrap_servers, topic, group_id)
        self.dashboard_data = defaultdict(dict)
        self.update_count = 0
    
    def update_dashboard(self, data: dict):
        """Update dashboard data structure"""
        symbol = data['symbol']
        
        self.dashboard_data[symbol] = {
            'symbol': symbol,
            'price': data['close'],
            'volume': data['volume'],
            'timestamp': data['timestamp'],
            'last_update': datetime.now().isoformat()
        }
        
        self.update_count += 1
        
        # Print dashboard update every 20 messages
        if self.update_count % 20 == 0:
            print(f"📊 Dashboard Update #{self.update_count}:")
            for sym, info in list(self.dashboard_data.items())[-5:]:  # Show last 5 symbols
                print(f"   {sym}: ${info['price']} (Vol: {info['volume']:,})")
            print()
    
    def process_message(self, message):
        """Process message for dashboard updates"""
        data = super().process_message(message)
        self.update_dashboard(data)
        return data

print("📋 Real-time Analytics Consumer Classes:")
print("   - AnalyticsConsumer: Moving averages, trends, volume analysis")
print("   - AlertConsumer: Price and volume alerts")
print("   - DashboardConsumer: Real-time dashboard updates")
print("   - RealTimeAnalyticsConsumer: Base class for custom implementations")
# Out:
# 📋 Real-time Analytics Consumer Classes:
#    - AnalyticsConsumer: Moving averages, trends, volume analysis
#    - AlertConsumer: Price and volume alerts
#    - DashboardConsumer: Real-time dashboard updates
#    - RealTimeAnalyticsConsumer: Base class for custom implementations

# %% [markdown]
# ## Exercise 1: High-Frequency Data Stream
#
# ### 🎯 **Learning Objectives:**
# - Generate high-frequency stock data
# - Understand real-time data processing challenges
# - Practice handling high-throughput streams
# - Learn about data generation patterns
#
# ### 📚 **Key Concepts:**
# 1. **High-Frequency Data**: Rapid data generation and processing
# 2. **Real-time Processing**: Handling data as it arrives
# 3. **Throughput**: Messages per second processing capability
# 4. **Data Quality**: Ensuring realistic and consistent data

# %%
# Exercise 1: Start High-Frequency Data Stream
print("🚀 Exercise 1: High-Frequency Data Stream Generation")

print("\n📊 Starting 30-second high-frequency stream...")
print("   This will generate ~300 messages at 0.1s intervals")
print("   Press Ctrl+C to stop early if needed")

# Start the high-frequency stream
producer.start_high_frequency_stream(
    duration_seconds=30,
    interval=ANALYTICS_CONFIG['high_frequency_interval']
)

print("\n✅ High-frequency stream completed!")
print("📈 Data is now available in the Kafka topic for real-time processing")
# Out:
# 🚀 Exercise 1: High-Frequency Data Stream Generation
#
# 📊 Starting 30-second high-frequency stream...
#    This will generate ~300 messages at 0.1s intervals
#    Press Ctrl+C to stop early if needed
# 🚀 Starting high-frequency stream for 30 seconds...
#    Interval: 0.1s between messages
#    Expected messages: ~300
# 📊 Sent 50 messages - Latest: MSFT $346.18
# 📊 Sent 100 messages - Latest: MSFT $359.58
# 📊 Sent 150 messages - Latest: NFLX $386.54
# 📊 Sent 200 messages - Latest: CRM $205.86
# 📊 Sent 250 messages - Latest: MSFT $357.62
# ✅ High-frequency stream completed!
#    Total messages sent: 278
#    Average rate: 9.3 messages/second
#
# ✅ High-frequency stream completed!
# 📈 Data is now available in the Kafka topic for real-time processing

# %% [markdown]
# ## Exercise 2: Real-time Analytics Processing
#
# ### 🎯 **Learning Objectives:**
# - Implement real-time analytics calculations
# - Practice moving average calculations
# - Learn trend detection algorithms
# - Understand volume analysis patterns
#
# ### 📚 **Key Concepts:**
# 1. **Moving Averages**: Smoothing price data over time windows
# 2. **Trend Detection**: Identifying price direction patterns
# 3. **Volume Analysis**: Understanding trading activity
# 4. **Real-time Calculations**: Processing data as it arrives

# %%
# Exercise 2: Real-time Analytics Processing
print("📈 Exercise 2: Real-time Analytics Processing")

print("\n🔧 Starting Analytics Consumer...")
print("   Processing messages for moving averages, trends, and volume analysis")

# Create analytics consumer
analytics_consumer = AnalyticsConsumer(
    KAFKA_BOOTSTRAP_SERVERS, 
    TOPIC_NAME, 
    CONSUMER_GROUPS['analytics']
)

analytics_consumer.create_consumer()

print("\n📊 Processing messages (will timeout after 10 seconds)...")
print("   Watch for analytics calculations below:")

# Process messages for 10 seconds
start_time = time.time()
timeout_seconds = 10

try:
    for message in analytics_consumer.consumer:
        if time.time() - start_time > timeout_seconds:
            print(f"\n⏰ Timeout reached after {timeout_seconds} seconds")
            break
            
        analytics_consumer.process_message(message)
        
except Exception as e:
    print(f"❌ Error during processing: {e}")
finally:
    if analytics_consumer.consumer:
        analytics_consumer.consumer.close()

# Show analytics results
print(f"\n📊 Analytics Processing Results:")
print(f"   ✅ Messages processed: {analytics_consumer.processed_count}")
print(f"   📈 Processing rate: {analytics_consumer.get_processing_rate():.1f} messages/second")
print(f"   📋 Analytics results: {len(analytics_consumer.analytics_results)} calculations")

if analytics_consumer.analytics_results:
    print(f"\n📈 Sample Analytics Results:")
    for result in analytics_consumer.analytics_results[-3:]:  # Show last 3
        print(f"   {result['symbol']}: ${result['close_price']} | MA: ${result['moving_average']} | Trend: {result['trend']} | Vol Ratio: {result['volume_ratio']}")

print("\n✅ Real-time analytics processing completed!")
# Out:
# 📈 Exercise 2: Real-time Analytics Processing
#
# 🔧 Starting Analytics Consumer...
#    Processing messages for moving averages, trends, and volume analysis
#
# 📊 Processing messages (will timeout after 10 seconds)...
#    Watch for analytics calculations below:
#
# 📊 Analytics Processing Results:
#    ✅ Messages processed: 0
#    📈 Processing rate: 0.0 messages/second
#    📋 Analytics results: 0 calculations
#
# ✅ Real-time analytics processing completed!

# %% [markdown]
# ## Exercise 3: Real-time Alert System
#
# ### 🎯 **Learning Objectives:**
# - Implement price change alerts
# - Practice volume spike detection
# - Learn alert threshold management
# - Understand real-time notification patterns
#
# ### 📚 **Key Concepts:**
# 1. **Price Alerts**: Detecting significant price movements
# 2. **Volume Alerts**: Identifying unusual trading activity
# 3. **Threshold Management**: Setting appropriate alert levels
# 4. **Real-time Notifications**: Immediate alert delivery

# %%
# Exercise 3: Real-time Alert System
print("🚨 Exercise 3: Real-time Alert System")

print("\n🔧 Starting Alert Consumer...")
print("   Monitoring for price changes and volume spikes")

# Create alert consumer
alert_consumer = AlertConsumer(
    KAFKA_BOOTSTRAP_SERVERS, 
    TOPIC_NAME, 
    CONSUMER_GROUPS['alerts']
)

alert_consumer.create_consumer()

print("\n📊 Processing messages for alerts (will timeout after 10 seconds)...")
print("   Watch for alerts below:")

# Process messages for 10 seconds
start_time = time.time()
timeout_seconds = 10

try:
    for message in alert_consumer.consumer:
        if time.time() - start_time > timeout_seconds:
            print(f"\n⏰ Timeout reached after {timeout_seconds} seconds")
            break
            
        alert_consumer.process_message(message)
        
except Exception as e:
    print(f"❌ Error during processing: {e}")
finally:
    if alert_consumer.consumer:
        alert_consumer.consumer.close()

# Show alert results
print(f"\n🚨 Alert System Results:")
print(f"   ✅ Messages processed: {alert_consumer.processed_count}")
print(f"   📈 Processing rate: {alert_consumer.get_processing_rate():.1f} messages/second")
print(f"   🚨 Price alerts triggered: {len(alert_consumer.price_alerts)}")
print(f"   📊 Volume alerts triggered: {len(alert_consumer.volume_alerts)}")

if alert_consumer.price_alerts:
    print(f"\n🚨 Price Alerts Summary:")
    for alert in alert_consumer.price_alerts[-3:]:  # Show last 3
        print(f"   {alert['symbol']}: {alert['change_percent']}% change (${alert['previous_price']} → ${alert['current_price']})")

if alert_consumer.volume_alerts:
    print(f"\n📊 Volume Alerts Summary:")
    for alert in alert_consumer.volume_alerts[-3:]:  # Show last 3
        print(f"   {alert['symbol']}: {alert['volume_ratio']}x volume spike ({alert['volume']:,} vs {alert['avg_volume']:,.0f})")

print("\n✅ Real-time alert system completed!")
# Out:
# 🚨 Exercise 3: Real-time Alert System
#
# 🔧 Starting Alert Consumer...
#    Monitoring for price changes and volume spikes
#
# 📊 Processing messages for alerts (will timeout after 10 seconds)...
#    Watch for alerts below:
# 📊 VOLUME ALERT: ADBE volume 2.0x average (284,967 vs 142,484)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (147,036 vs 73,518)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (141,893 vs 70,946)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (510,438 vs 255,219)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (73,399 vs 36,700)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (117,077 vs 58,538)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (204,760 vs 102,380)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (788,245 vs 394,122)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (404,203 vs 202,102)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (278,929 vs 139,464)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (97,147 vs 48,574)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (160,928 vs 80,464)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (382,714 vs 191,357)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (405,116 vs 202,558)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (148,990 vs 74,495)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (58,383 vs 29,192)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (628,711 vs 314,356)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (275,700 vs 137,850)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (233,194 vs 116,597)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (721,992 vs 360,996)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (157,980 vs 78,990)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (352,445 vs 176,222)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (460,203 vs 230,102)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (209,673 vs 104,836)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (309,883 vs 154,942)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (313,522 vs 156,761)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (76,548 vs 38,274)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (304,958 vs 152,479)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (246,447 vs 123,224)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (163,538 vs 81,769)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (756,616 vs 378,308)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (663,560 vs 331,780)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (81,841 vs 40,920)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (515,252 vs 257,626)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (282,435 vs 141,218)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (375,305 vs 187,652)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (450,466 vs 225,233)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (97,005 vs 48,502)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (185,727 vs 92,864)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (201,193 vs 100,596)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (331,670 vs 165,835)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (235,739 vs 117,870)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (408,088 vs 204,044)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (281,952 vs 140,976)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (163,687 vs 81,844)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (262,416 vs 131,208)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (116,446 vs 58,223)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (76,349 vs 38,174)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (349,014 vs 174,507)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (290,539 vs 145,270)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (235,251 vs 117,626)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (541,760 vs 270,880)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (421,976 vs 210,988)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (336,211 vs 168,106)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (963,688 vs 481,844)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (335,097 vs 167,548)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (312,122 vs 156,061)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (270,886 vs 135,443)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (257,651 vs 128,826)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (138,003 vs 69,002)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (442,293 vs 221,146)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (564,263 vs 282,132)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (111,972 vs 55,986)
# 🚨 PRICE ALERT: ADBE changed 5.51% from $499.76 to $527.3
# 📊 VOLUME ALERT: ADBE volume 2.0x average (120,685 vs 60,342)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (250,084 vs 125,042)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (134,603 vs 67,302)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (304,765 vs 152,382)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (204,326 vs 102,163)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (163,374 vs 81,687)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (309,405 vs 154,702)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (255,098 vs 127,549)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (270,446 vs 135,223)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (455,152 vs 227,576)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (266,911 vs 133,456)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (392,826 vs 196,413)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (615,145 vs 307,572)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (164,614 vs 82,307)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (318,981 vs 159,490)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (324,407 vs 162,204)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (579,952 vs 289,976)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (163,807 vs 81,904)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (73,473 vs 36,736)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (347,448 vs 173,724)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (248,567 vs 124,284)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (217,779 vs 108,890)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (600,034 vs 300,017)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (435,548 vs 217,774)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (34,326 vs 17,163)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (104,913 vs 52,456)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (501,240 vs 250,620)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (422,532 vs 211,266)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (555,566 vs 277,783)
# 🚨 PRICE ALERT: NVDA changed 5.24% from $446.98 to $470.39
# 📊 VOLUME ALERT: NVDA volume 2.0x average (161,856 vs 80,928)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (257,349 vs 128,674)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (47,572 vs 23,786)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (265,254 vs 132,627)
# 📊 VOLUME ALERT: AMZN volume 2.0x average (158,001 vs 79,000)
# 📊 VOLUME ALERT: NVDA volume 2.0x average (648,398 vs 324,199)
# 📊 VOLUME ALERT: ADBE volume 2.0x average (52,193 vs 26,096)
# 📊 VOLUME ALERT: TSLA volume 2.0x average (81,282 vs 40,641)
# 📊 VOLUME ALERT: META volume 2.0x average (216,361 vs 108,180)
# 📊 VOLUME ALERT: META volume 2.0x average (179,371 vs 89,686)
# 📊 VOLUME ALERT: META volume 2.0x average (346,978 vs 173,489)
# 📊 VOLUME ALERT: META volume 2.0x average (346,479 vs 173,240)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (166,283 vs 83,142)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (662,143 vs 331,072)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (260,908 vs 130,454)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (205,913 vs 102,956)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (651,458 vs 325,729)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (471,772 vs 235,886)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (787,315 vs 393,658)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (281,228 vs 140,614)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (331,655 vs 165,828)
# 📊 VOLUME ALERT: META volume 2.0x average (407,961 vs 203,980)
# 📊 VOLUME ALERT: META volume 2.0x average (278,769 vs 139,384)
# 📊 VOLUME ALERT: META volume 2.0x average (232,440 vs 116,220)
# 📊 VOLUME ALERT: META volume 2.0x average (161,430 vs 80,715)
# 📊 VOLUME ALERT: META volume 2.0x average (161,348 vs 80,674)
# 📊 VOLUME ALERT: META volume 2.0x average (107,979 vs 53,990)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (247,187 vs 123,594)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (253,070 vs 126,535)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (288,253 vs 144,126)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (239,312 vs 119,656)
# 📊 VOLUME ALERT: META volume 2.0x average (313,877 vs 156,938)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (256,205 vs 128,102)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (107,402 vs 53,701)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (318,169 vs 159,084)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (170,671 vs 85,336)
# 📊 VOLUME ALERT: META volume 2.0x average (274,347 vs 137,174)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (234,151 vs 117,076)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (65,158 vs 32,579)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (107,838 vs 53,919)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (154,583 vs 77,292)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (300,579 vs 150,290)
# 📊 VOLUME ALERT: META volume 2.0x average (342,383 vs 171,192)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (624,115 vs 312,058)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (525,370 vs 262,685)
# 📊 VOLUME ALERT: META volume 2.0x average (298,801 vs 149,400)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (116,677 vs 58,338)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (270,226 vs 135,113)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (710,374 vs 355,187)
# 📊 VOLUME ALERT: META volume 2.0x average (584,122 vs 292,061)
# 📊 VOLUME ALERT: META volume 2.0x average (764,849 vs 382,424)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (233,201 vs 116,600)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (366,698 vs 183,349)
# 📊 VOLUME ALERT: META volume 2.0x average (166,251 vs 83,126)
# 📊 VOLUME ALERT: META volume 2.0x average (620,791 vs 310,396)
# 📊 VOLUME ALERT: META volume 2.0x average (135,365 vs 67,682)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (516,536 vs 258,268)
# 📊 VOLUME ALERT: META volume 2.0x average (543,432 vs 271,716)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (294,817 vs 147,408)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (231,467 vs 115,734)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (255,198 vs 127,599)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (517,706 vs 258,853)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (827,723 vs 413,862)
# 📊 VOLUME ALERT: META volume 2.0x average (441,659 vs 220,830)
# 🚨 PRICE ALERT: META changed 5.25% from $303.89 to $319.85
# 📊 VOLUME ALERT: META volume 2.0x average (932,929 vs 466,464)
# 📊 VOLUME ALERT: META volume 2.0x average (357,962 vs 178,981)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (315,383 vs 157,692)
# 📊 VOLUME ALERT: META volume 2.0x average (503,161 vs 251,580)
# 📊 VOLUME ALERT: META volume 2.0x average (161,403 vs 80,702)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (649,920 vs 324,960)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (154,161 vs 77,080)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (151,439 vs 75,720)
# 📊 VOLUME ALERT: META volume 2.0x average (466,798 vs 233,399)
# 📊 VOLUME ALERT: META volume 2.0x average (251,210 vs 125,605)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (295,458 vs 147,729)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (108,137 vs 54,068)
# 📊 VOLUME ALERT: META volume 2.0x average (120,866 vs 60,433)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (266,662 vs 133,331)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (352,516 vs 176,258)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (336,994 vs 168,497)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (307,514 vs 153,757)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (98,624 vs 49,312)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (230,604 vs 115,302)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (305,024 vs 152,512)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (569,001 vs 284,500)
# 📊 VOLUME ALERT: AAPL volume 2.0x average (365,859 vs 182,930)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (692,958 vs 346,479)
# 📊 VOLUME ALERT: MSFT volume 2.0x average (297,661 vs 148,830)
# 📊 VOLUME ALERT: CRM volume 2.0x average (624,489 vs 312,244)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (86,349 vs 43,174)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (47,200 vs 23,600)
# 📊 VOLUME ALERT: CRM volume 2.0x average (808,692 vs 404,346)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (170,118 vs 85,059)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (255,411 vs 127,706)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (390,300 vs 195,150)
# 📊 VOLUME ALERT: CRM volume 2.0x average (124,359 vs 62,180)
# 📊 VOLUME ALERT: CRM volume 2.0x average (456,115 vs 228,058)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (90,369 vs 45,184)
# 📊 VOLUME ALERT: CRM volume 2.0x average (400,939 vs 200,470)
# 📊 VOLUME ALERT: CRM volume 2.0x average (104,034 vs 52,017)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (91,518 vs 45,759)
# 📊 VOLUME ALERT: CRM volume 2.0x average (240,545 vs 120,272)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (627,500 vs 313,750)
# 📊 VOLUME ALERT: CRM volume 2.0x average (96,061 vs 48,030)
# 📊 VOLUME ALERT: CRM volume 2.0x average (467,867 vs 233,934)
# 📊 VOLUME ALERT: CRM volume 2.0x average (364,050 vs 182,025)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (537,369 vs 268,684)
# 📊 VOLUME ALERT: CRM volume 2.0x average (518,155 vs 259,078)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (187,280 vs 93,640)
# 📊 VOLUME ALERT: CRM volume 2.0x average (298,412 vs 149,206)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (135,654 vs 67,827)
# 📊 VOLUME ALERT: CRM volume 2.0x average (405,753 vs 202,876)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (486,065 vs 243,032)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (140,832 vs 70,416)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (388,300 vs 194,150)
# 📊 VOLUME ALERT: CRM volume 2.0x average (442,091 vs 221,046)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (164,267 vs 82,134)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (351,949 vs 175,974)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (193,533 vs 96,766)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (56,625 vs 28,312)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (251,269 vs 125,634)
# 📊 VOLUME ALERT: CRM volume 2.0x average (52,912 vs 26,456)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (302,731 vs 151,366)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (415,271 vs 207,636)
# 📊 VOLUME ALERT: CRM volume 2.0x average (112,733 vs 56,366)
# 📊 VOLUME ALERT: CRM volume 2.0x average (517,749 vs 258,874)
# 📊 VOLUME ALERT: CRM volume 2.0x average (88,558 vs 44,279)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (899,558 vs 449,779)
# 📊 VOLUME ALERT: CRM volume 2.0x average (452,670 vs 226,335)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (131,357 vs 65,678)
# 🚨 PRICE ALERT: CRM changed 5.07% from $200.01 to $210.15
# 📊 VOLUME ALERT: CRM volume 2.0x average (34,125 vs 17,062)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (360,110 vs 180,055)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (275,715 vs 137,858)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (264,129 vs 132,064)
# 📊 VOLUME ALERT: CRM volume 2.0x average (388,158 vs 194,079)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (502,049 vs 251,024)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (448,510 vs 224,255)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (182,296 vs 91,148)
# 🚨 PRICE ALERT: GOOGL changed 5.41% from $2839.59 to $2993.15
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (509,415 vs 254,708)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (662,699 vs 331,350)
# 🚨 PRICE ALERT: NFLX changed 6.17% from $402.26 to $377.46
# 📊 VOLUME ALERT: NFLX volume 2.0x average (633,635 vs 316,818)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (240,624 vs 120,312)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (751,334 vs 375,667)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (786,478 vs 393,239)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (631,398 vs 315,699)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (351,828 vs 175,914)
# 📊 VOLUME ALERT: CRM volume 2.0x average (548,452 vs 274,226)
# 📊 VOLUME ALERT: CRM volume 2.0x average (476,070 vs 238,035)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (394,106 vs 197,053)
# 📊 VOLUME ALERT: CRM volume 2.0x average (420,227 vs 210,114)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (72,266 vs 36,133)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (641,247 vs 320,624)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (506,890 vs 253,445)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (961,103 vs 480,552)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (706,716 vs 353,358)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (180,472 vs 90,236)
# 📊 VOLUME ALERT: CRM volume 2.0x average (303,985 vs 151,992)
# 📊 VOLUME ALERT: CRM volume 2.0x average (492,329 vs 246,164)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (196,300 vs 98,150)
# 📊 VOLUME ALERT: CRM volume 2.0x average (135,222 vs 67,611)
# 📊 VOLUME ALERT: CRM volume 2.0x average (118,566 vs 59,283)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (496,889 vs 248,444)
# 📊 VOLUME ALERT: CRM volume 2.0x average (152,818 vs 76,409)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (561,786 vs 280,893)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (477,810 vs 238,905)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (211,605 vs 105,802)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (216,845 vs 108,422)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (414,120 vs 207,060)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (639,853 vs 319,926)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (440,568 vs 220,284)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (210,579 vs 105,290)
# 📊 VOLUME ALERT: CRM volume 2.0x average (427,564 vs 213,782)
# 📊 VOLUME ALERT: CRM volume 2.0x average (323,668 vs 161,834)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (460,023 vs 230,012)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (158,162 vs 79,081)
# 📊 VOLUME ALERT: CRM volume 2.0x average (515,788 vs 257,894)
# 📊 VOLUME ALERT: CRM volume 2.0x average (435,327 vs 217,664)
# 📊 VOLUME ALERT: CRM volume 2.0x average (143,404 vs 71,702)
# 📊 VOLUME ALERT: NFLX volume 2.0x average (697,072 vs 348,536)
# 📊 VOLUME ALERT: CRM volume 2.0x average (626,305 vs 313,152)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (48,655 vs 24,328)
# 📊 VOLUME ALERT: CRM volume 2.0x average (697,239 vs 348,620)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (147,616 vs 73,808)
# 🚨 PRICE ALERT: GOOGL changed 5.04% from $2993.15 to $2842.34
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (340,086 vs 170,043)
# 📊 VOLUME ALERT: CRM volume 2.0x average (255,161 vs 127,580)
# 📊 VOLUME ALERT: GOOGL volume 2.0x average (283,796 vs 141,898)
#
# 🚨 Alert System Results:
#    ✅ Messages processed: 278
#    📈 Processing rate: 273.3 messages/second
#    🚨 Price alerts triggered: 7
#    📊 Volume alerts triggered: 278
#
# 🚨 Price Alerts Summary:
#    GOOGL: 5.41% change ($2839.59 → $2993.15)
#    NFLX: 6.17% change ($402.26 → $377.46)
#    GOOGL: 5.04% change ($2993.15 → $2842.34)
#
# 📊 Volume Alerts Summary:
#    GOOGL: 2.0x volume spike (340,086 vs 170,043)
#    CRM: 2.0x volume spike (255,161 vs 127,580)
#    GOOGL: 2.0x volume spike (283,796 vs 141,898)
#
# ✅ Real-time alert system completed!
